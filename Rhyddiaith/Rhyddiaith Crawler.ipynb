# %%
import re
import json
import pandas as pd
import urllib.request
from bs4 import BeautifulSoup

# %%
def download_page(link):
    req = urllib.request.Request(link)
    with urllib.request.urlopen(req) as response:
        html = response.read()
    soup = BeautifulSoup(html, 'html.parser')
    return soup

# %%
base = "http://www.rhyddiaithganoloesol.caerdydd.ac.uk/en/"
mss_list = download_page("http://www.rhyddiaithganoloesol.caerdydd.ac.uk/en/manuscripts.php")

# %%
data = []
for link in mss_list.table.find_all('a'):
    ms = {}
    ms['ms_title'] = link.text
    ms['ms_link'] = base + link.get('href')
    ms['header_link'] = ms['ms_link'].replace("ms-home", "tei-header")
    data.append(ms)

# %%
dates = ["1275–1325", "1300–1350", "1350", "1350–1400", "1375–1425", "1400–1450"]

for ms in data[:6]:
    ms['date'] = dates[0]
    
for ms in data[6:24]:
    ms['date'] = dates[1]
    
for ms in data[24:36]:
    ms['date'] = dates[2]
    
for ms in data[36:39]:
    ms['date'] = dates[3]
    
for ms in data[39:-1]:
    ms['date'] = dates[4]
    
data[-1]['date'] = dates[5]

# %%
data[-3:]
# Out:
# [{'ms_title': 'NLW MS. Peniarth 19',
#   'ms_link': 'http://www.rhyddiaithganoloesol.caerdydd.ac.uk/en/ms-home.php?ms=Pen19',
#   'header_link': 'http://www.rhyddiaithganoloesol.caerdydd.ac.uk/en/tei-header.php?ms=Pen19',
#   'date': '1375–1425'},
#  {'ms_title': 'NLW MS. Llanstephan 4',
#   'ms_link': 'http://www.rhyddiaithganoloesol.caerdydd.ac.uk/en/ms-home.php?ms=Llst4',
#   'header_link': 'http://www.rhyddiaithganoloesol.caerdydd.ac.uk/en/tei-header.php?ms=Llst4',
#   'date': '1375–1425'},
#  {'ms_title': 'NLW MS. Peniarth 33',
#   'ms_link': 'http://www.rhyddiaithganoloesol.caerdydd.ac.uk/en/ms-home.php?ms=Pen33',
#   'header_link': 'http://www.rhyddiaithganoloesol.caerdydd.ac.uk/en/tei-header.php?ms=Pen33',
#   'date': '1400–1450'}]

# %%
for ms in data:
    ms['contents'] = []
    header = download_page(ms['header_link'])
    rows = header.table.find_all('tr')[1:]
    for row in rows:
        cells = row.find_all('td')
        if len(cells) == 3:
            ms['contents'].append({'folio': cells[0].text, 'columns': '—', 'text': cells[1].text, 'scribe': cells[2].text})
        elif len(cells) == 4:
            ms['contents'].append({'folio': cells[0].text, 'columns': cells[1].text, 'text': cells[2].text, 'scribe': cells[3].text})
        
        elif len(cells) == 5:
            ms['contents'].append({'folio': cells[1].text, 'columns': cells[2].text, 'text': cells[3].text, 'scribe': cells[4].text})

# %%
data[0]
# Out:
# {'ms_title': 'NLW MS. Peniarth 16 part i',
#  'ms_link': 'http://www.rhyddiaithganoloesol.caerdydd.ac.uk/en/ms-home.php?ms=Pen16i',
#  'header_link': 'http://www.rhyddiaithganoloesol.caerdydd.ac.uk/en/tei-header.php?ms=Pen16i',
#  'date': '1275–1325',
#  'contents': [{'folio': '1r-2v',
#    'columns': '—',
#    'text': 'table of contents, not transcribed',
#    'scribe': 'later hand'},
#   {'folio': '3r-4v', 'columns': '—', 'text': 'blank', 'scribe': '-'},
#   {'folio': '5r-6r',
#    'columns': '—',
#    'text': 'Pwyll y Pader o ddull Awstin Sant',
#    'scribe': 'Peniarth 16 hand A'},
#   {'folio': '6r-9r',
#    'columns': '—',
#    'text': 'Pwyll y Pader o ddull Hu Sant',
#    'scribe': 'Peniarth 16 hand A'},
#   {'folio': '9r-11r',
#    'columns': '—',
#    'text': 'Deuddeg Pwnc y Gredo',
#    'scribe': 'Peniarth 16 hand B'}]}

# %%
with open('rhyddiaith.json', 'w', encoding='utf-8') as f:
    json.dump(data, f, ensure_ascii = False)

# %%
texts = []

for m in data:
    date = m["date"]
    ms = m["ms_title"]
    for t in m["contents"]:
        text = t["text"]
        folio = t["folio"]
        columns = t["columns"]
        scribe = t["scribe"]
        texts.append({"text": text, "date": date, "manuscript": ms, "folio": folio, "columns": columns, "scribe": scribe})

# %%
texts[-85]
# Out:
# {'text': 'Diarhebion',
#  'date': '1375–1425',
#  'manuscript': 'Oxford Jesus College MS. 111 (The Red Book of Hergest)',
#  'folio': '264r-270v',
#  'columns': '1057-1083',
#  'scribe': 'Hywel Fychan'}

# %%
len(texts)
# Out:
# 843

# %%
with open('rhyddiaith_texts.json', 'w', encoding='utf-8') as f:
    json.dump(texts, f, ensure_ascii = False)

# %%
text_names = [t['text'] for t in texts]
dates = [t['date'] for t in texts]
ms_names = [t['manuscript'] for t in texts]
folios = [t['folio'] for t in texts]
columns = [t['columns'] for t in texts]
scribes = [t['scribe'] for t in texts]

df_dict = {"text": text_names, "date": dates, "manuscript": ms_names, "folio": folios, "columns": columns, "scribe": scribes}

df = pd.DataFrame.from_dict(df_dict)
df.head()
# Out:
#                                  text       date                  manuscript  \
# 0  table of contents, not transcribed  1275–1325  NLW MS. Peniarth 16 part i
# 1                               blank  1275–1325  NLW MS. Peniarth 16 part i
# 2   Pwyll y Pader o ddull Awstin Sant  1275–1325  NLW MS. Peniarth 16 part i
# 3       Pwyll y Pader o ddull Hu Sant  1275–1325  NLW MS. Peniarth 16 part i
# 4                Deuddeg Pwnc y Gredo  1275–1325  NLW MS. Peniarth 16 part i
#
#     folio columns              scribe
# 0   1r-2v       —          later hand
# 1   3r-4v       —                   -
# 2   5r-6r       —  Peniarth 16 hand A
# 3   6r-9r       —  Peniarth 16 hand A
# 4  9r-11r       —  Peniarth 16 hand B

# %%
df.tail()
# Out:
#                                                   text       date  \
# 838  Notes on the locations of a number of tracts i...  1400–1450
# 839             Signature of William Morris dated 1662  1400–1450
# 840      Mixed notes on the contents of the manuscript  1400–1450
# 841           Note in the hand of J. Gwenogvryn Evans?  1400–1450
# 842                                    Llyfr Blegywryd  1400–1450
#
#               manuscript  folio columns              scribe
# 838  NLW MS. Peniarth 33     iv       —                   >
# 839  NLW MS. Peniarth 33      v       —     William Maurice
# 840  NLW MS. Peniarth 33     vi       —             unknown
# 841  NLW MS. Peniarth 33    vii       —              ?Evans
# 842  NLW MS. Peniarth 33  1-186       —  Peniarth 33 hand A

# %%
df.to_csv("rhyddiaith_texts.tsv", sep="\t", encoding="utf-8", index=False)

# %%
for item in data:
    print(item['ms_title'])
# Out:
# NLW MS. Peniarth 16 part i
# NLW MS. Peniarth 8 part i
# NLW MS. Peniarth 8 part ii
# NLW MS. Peniarth 7
# NLW MS. Peniarth 21
# NLW MS. Peniarth 3 part ii
# Cambridge Trinity College MS. O.7.1
# NLW MS. Peniarth 36A
# NLW MS. Peniarth 36B
# Bodorgan MS.
# NLW MS. 3036 (Mostyn 117)
# BL Cotton Cleopatra MS. A XIV
# NLW MS. Peniarth 6 part iv
# BL Harley MS. 4353
# NLW MS. Peniarth 31
# NLW MS. Peniarth 35
# NLW MS. Peniarth 37
# NLW MS. Peniarth 45
# NLW MS. Peniarth 9
# NLW MS. Peniarth 20
# BL Cotton Cleopatra MS. B V part i
# BL Cotton Cleopatra MS. B V part iii
# Cardiff MS. 1.363 (Hafod 2)
# NLW MS. Peniarth 14, pp.101-90
# Cardiff MS. 1.362 (Hafod 1)
# BL Cotton Cleopatra MS. B V part ii
# NLW MS. Peniarth 10
# Oxford Jesus College MS. 119 (The Book of the Anchorite of Llanddewi Brefi)
# NLW MS. Peniarth 18
# NLW MS. Peniarth 46
# NLW MS. Peniarth 47 part i
# NLW MS. Peniarth 5 (The White Book of Rhydderch, part 1)
# NLW MS. Peniarth 4 (The White Book of Rhydderch, part 2)
# BL Cotton Titus MS. D IX
# BL Harley MS. 958
# NLW MS. 24029 (Boston 5)
# NLW MS. 3035 (Mostyn 116)
# BL Additional MS. 19,709
# NLW MS. 20143A
# Oxford Jesus College MS. 20
# NLW MS. Peniarth 15
# BL Additional MS. 14,912
# Oxford Rawlinson MS. B 467
# Shrewsbury MS. 11
# NLW MS. Peniarth 38
# Cardiff MS. 3.242 (Hafod 16)
# NLW MS. Peniarth 11
# NLW MS. Llanstephan 27 (The Red Book of Talgarth)
# NLW MS. Peniarth 12 part ii
# Philadelphia MS. 8680
# Oxford Jesus College MS. 57
# Oxford Jesus College MS. 111 (The Red Book of Hergest)
# NLW MS. Peniarth 32 (Y Llyfr Teg)
# NLW MS. Peniarth 190
# NLW MS. Peniarth 19
# NLW MS. Llanstephan 4
# NLW MS. Peniarth 33

# %%
data[-6]
# Out:
# {'ms_title': 'Oxford Jesus College MS. 111 (The Red Book of Hergest)',
#  'ms_link': 'http://www.rhyddiaithganoloesol.caerdydd.ac.uk/en/ms-home.php?ms=Jesus111',
#  'header_link': 'http://www.rhyddiaithganoloesol.caerdydd.ac.uk/en/tei-header.php?ms=Jesus111',
#  'date': '1375–1425',
#  'contents': [{'folio': '1r-8r',
#    'columns': '1-29.39',
#    'text': 'Ystoria Dared',
#    'scribe': 'Red Book hand A'},
#   {'folio': '8r',
#    'columns': '29.39-30',
#    'text': 'Ystoria Dared',
#    'scribe': 'Hywel Fychan'},
#   {'folio': '8v-26v',
#    'columns': '31-104',
#    'text': 'Brut y Brenhinoedd',
#    'scribe': 'Red Book hand A'},
#   {'folio': '', 'columns': '', 'text': 'folios missing', 'scribe': ''},
#   {'folio': '27r-58r',
#    'columns': '105-230.11',
#    'text': 'Brut y Brenhinoedd',
#    'scribe': 'Red Book hand AI'},
#   {'folio': '58r-89v',
#    'columns': '230.20-319, 340-376.8',
#    'text': 'Brut y Tywysogion',
#    'scribe': 'Red Book hand A'},
#   {'folio': '89v-90r',
#    'columns': '376.9-377.18',
#    'text': 'Gildas Hen Broffwyd',
#    'scribe': 'Hywel Fychan'},
#   {'folio': '90r-90v',
#    'columns': '377.23-380',
#    'text': 'Cantrefi a Chymydau Cymru',
#    'scribe': 'Hywel Fychan'},
#   {'folio': '91r-98r',
#    'columns': '381-409',
#    'text': 'Ystoria Carolo Magno: Chronicl Turpin',
#    'scribe': 'Red Book hand A'},
#   {'folio': '98r-111r',
#    'columns': '409-460',
#    'text': 'Ystoria Carolo Magno: Rhamant Otfel',
#    'scribe': 'Red Book hand A'},
#   {'folio': '111r-114v',
#    'columns': '460-475',
#    'text': 'Ystoria Carolo Magno: Cân Rolant',
#    'scribe': 'Red Book hand A'},
#   {'folio': '',
#    'columns': '',
#    'text': "A note in YCM states that a leaf is missing here. According to Gifford Charles Edwards's collation of the manuscript, however, there is no leaf missing; rather, the catchword at the bottom of 114v does not correspond to the first word of 115r.",
#    'scribe': ''},
#   {'folio': '115r-117r',
#    'columns': '476-484',
#    'text': 'Ystoria Carolo Magno: Cân Rolant',
#    'scribe': 'Red Book hand A'},
#   {'folio': '117r-121v',
#    'columns': '484-502',
#    'text': 'Ystoria Carolo Magno: Chronicl Turpin',
#    'scribe': 'Red Book hand A'},
#   {'folio': '121v-125r',
#    'columns': '502-516',
#    'text': "Delw'r Byd",
#    'scribe': 'Hywel Fychan'},
#   {'folio': '125r-125v',
#    'columns': '516-518',
#    'text': 'Chronicle',
#    'scribe': 'Hywel Fychan'},
#   {'folio': '126r-127v',
#    'columns': '520-527',
#    'text': 'Hwsmonaeth',
#    'scribe': 'Hywel Fychan'},
#   {'folio': '127v-134v',
#    'columns': '527-555',
#    'text': 'Saith Doethion Rhufain',
#    'scribe': 'Hywel Fychan'},
#   {'folio': '134v-138v',
#    'columns': '555-571',
#    'text': 'Breuddwyd Rhonabwy',
#    'scribe': 'Hywel Fychan'},
#   {'folio': '139r-141r',
#    'columns': '571a-577',
#    'text': 'Proffwydoliaeth Sibli Ddoeth',
#    'scribe': 'Hywel Fychan'},
#   {'folio': '141r-142v',
#    'columns': '577-583',
#    'text': 'Kyvoessi myrdin a gwendyd y chwaer, not transcribed',
#    'scribe': 'Hywel Fychan'},
#   {'folio': '143r',
#    'columns': '584-585',
#    'text': 'Gwasgardgerd vyrdin yn y bed, not transcribed',
#    'scribe': 'Hywel Fychan'},
#   {'folio': '143r',
#    'columns': '585',
#    'text': 'Sant Awstin am dewder y ddaear',
#    'scribe': 'Hywel Fychan'},
#   {'folio': '143r',
#    'columns': '585',
#    'text': 'Hyn a ddywedodd yr Enaid',
#    'scribe': 'Hywel Fychan'},
#   {'folio': '143r-144r',
#    'columns': '585-588',
#    'text': 'Yr Eryr yng Nghaer Septon',
#    'scribe': 'Hywel Fychan'},
#   {'folio': '144r',
#    'columns': '588',
#    'text': 'Trioedd Ynys Prydain',
#    'scribe': 'Hywel Fychan'},
#   {'folio': '144r',
#    'columns': '588-589',
#    'text': 'Pan aeth llu i Lychlyn',
#    'scribe': 'Hywel Fychan'},
#   {'folio': '144r-147r',
#    'columns': '589-600',
#    'text': 'Trioedd Ynys Prydain',
#    'scribe': 'Hywel Fychan'},
#   {'folio': '147r',
#    'columns': '600',
#    'text': 'Cas Bethau',
#    'scribe': 'Hywel Fychan'},
#   {'folio': '147r-148r',
#    'columns': '600-604',
#    'text': 'Enwau ac Anrhyfeddodau Ynys Prydain',
#    'scribe': 'Hywel Fychan'},
#   {'folio': '148v', 'columns': '', 'text': 'blank', 'scribe': ''},
#   {'folio': '149r-154r',
#    'columns': '605-626',
#    'text': 'Ystoria Carolo Magno: Pererindod Siarlymaen',
#    'scribe': 'Red Book hand A'},
#   {'folio': '154v-161v',
#    'columns': '627-655',
#    'text': 'Owain',
#    'scribe': 'Hywel Fychan'},
#   {'folio': '161v-172r',
#    'columns': '655-697',
#    'text': 'Peredur',
#    'scribe': 'Hywel Fychan'},
#   {'folio': '172r-174r',
#    'columns': '697-705',
#    'text': 'Breuddwyd Macsen',
#    'scribe': 'Hywel Fychan'},
#   {'folio': '174r-175r',
#    'columns': '705-710',
#    'text': 'Cyfranc Lludd a Llefelys',
#    'scribe': 'Hywel Fychan'},
#   {'folio': '175r-179v',
#    'columns': '710-726',
#    'text': 'Y gainc gyntaf',
#    'scribe': 'Hywel Fychan'},
#   {'folio': '179v-182v',
#    'columns': '726-739',
#    'text': 'Yr ail gainc',
#    'scribe': 'Hywel Fychan'},
#   {'folio': '182v-185v',
#    'columns': '739-751',
#    'text': 'Y drydedd gainc',
#    'scribe': 'Hywel Fychan'},
#   {'folio': '185v-190r',
#    'columns': '751-769',
#    'text': 'Y bedwaredd gainc',
#    'scribe': 'Hywel Fychan'},
#   {'folio': '190r-200r',
#    'columns': '769-809',
#    'text': 'Geraint',
#    'scribe': 'Hywel Fychan'},
#   {'folio': '200v-210r',
#    'columns': '810-844',
#    'text': 'Culhwch ac Olwen',
#    'scribe': 'Hywel Fychan'},
#   {'folio': '210r-231r',
#    'columns': '845-928',
#    'text': 'Ystoria Bown de Hamtwn',
#    'scribe': 'Hywel Fychan'},
#   {'folio': '231r-233v',
#    'columns': '928-939',
#    'text': 'Meddyginiaethau',
#    'scribe': 'Hywel Fychan'},
#   {'folio': '233v',
#    'columns': '939',
#    'text': 'Y Misoedd',
#    'scribe': 'Hywel Fychan'},
#   {'folio': '234r',
#    'columns': '940',
#    'text': 'Gollwng Gwaed',
#    'scribe': 'Hywel Fychan'},
#   {'folio': '234r',
#    'columns': '940-941',
#    'text': 'Argoelion y Flwyddyn',
#    'scribe': 'Hywel Fychan'},
#   {'folio': '234r-235r',
#    'columns': '941-945',
#    'text': 'Meddyginiaethau',
#    'scribe': 'Hywel Fychan'},
#   {'folio': '235r-235v',
#    'columns': '945-947',
#    'text': "Campau'r Cennin",
#    'scribe': 'Hywel Fychan'},
#   {'folio': '235v-236v',
#    'columns': '947-950',
#    'text': "Ansoddau'r Trwnc",
#    'scribe': 'Hywel Fychan'},
#   {'folio': '236v',
#    'columns': '950-951',
#    'text': 'Meddyginiaethau',
#    'scribe': 'Hywel Fychan'},
#   {'folio': '236v-237r',
#    'columns': '951-955',
#    'text': 'Latin medical text, not transcribed',
#    'scribe': 'Hywel Fychan'},
#   {'folio': '237v-238r',
#    'columns': '955-956',
#    'text': 'Meddyginiaethau',
#    'scribe': 'Hywel Fychan'},
#   {'folio': '238r-238v',
#    'columns': '956-959',
#    'text': 'Llythyr Aristotlys at Alecsander: Rheolau Iechyd',
#    'scribe': 'Hywel Fychan'},
#   {'folio': '239r-242v',
#    'columns': '960-974',
#    'text': 'Diarhebion',
#    'scribe': 'Hywel Fychan'},
#   {'folio': '242v',
#    'columns': '974-975',
#    'text': 'Mabiaith Hengyrys o Iâl',
#    'scribe': 'Hywel Fychan'},
#   {'folio': '242v-248v',
#    'columns': '975-998',
#    'text': "Delw'r Byd",
#    'scribe': 'Hywel Fychan'},
#   {'folio': '248v',
#    'columns': '998-999',
#    'text': "O'r Ddaear hyd at y Lloer",
#    'scribe': 'Hywel Fychan'},
#   {'folio': '248v-253v',
#    'columns': '999-1019',
#    'text': 'Brut y Saeson',
#    'scribe': 'Hywel Fychan'},
#   {'folio': '254r-254v',
#    'columns': '1020-1022',
#    'text': 'O Oes Gwrtheyrn Gwrthenau',
#    'scribe': 'Hywel Fychan'},
#   {'folio': '254v', 'columns': '1023', 'text': 'blank', 'scribe': ''},
#   {'folio': '255r', 'columns': '', 'text': 'blank', 'scribe': ''},
#   {'folio': '255v-263v',
#    'columns': '1024-1057',
#    'text': 'Poetry, not transcribed',
#    'scribe': 'Hywel Fychan'},
#   {'folio': '264r-270v',
#    'columns': '1057-1083',
#    'text': 'Diarhebion',
#    'scribe': 'Hywel Fychan'},
#   {'folio': '271r-278v',
#    'columns': '1085-1115',
#    'text': 'Amlyn ac Amig',
#    'scribe': 'Hywel Fychan'},
#   {'folio': '278v', 'columns': '1116', 'text': 'blank', 'scribe': ''},
#   {'folio': '279r-285r',
#    'columns': '1117-1142',
#    'text': 'Gramadeg y Penceirddiaid',
#    'scribe': 'Hywel Fychan'},
#   {'folio': '285v-302v',
#    'columns': '1142-1212',
#    'text': 'Poetry, not transcribed',
#    'scribe': 'Hywel Fychan and X91'}]}
